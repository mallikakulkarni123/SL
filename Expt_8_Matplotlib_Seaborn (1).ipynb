# %% [markdown]
# # Matplotlib

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Line graph

# %%
import matplotlib.pyplot as plt

days = [1,2,3,4,5,6,7]
temp = [32 , 34 , 35 , 31 , 36 , 29 , 27]
plt.plot(days , temp)

# %%
plt.plot(days , temp)
plt.xlabel('DAYS DATA')
plt.ylabel('TEMP RECORDS')
plt.title('Weather information')
# Out:
# Text(0.5, 1.0, 'Weather information')

# %%
plt.plot(days , temp , c = 'r' , marker = '>' , ls = ':')

plt.xlabel('DAYS DATA')
plt.ylabel('TEMP RECORDS')
plt.title('Weather information')
# Out:
# Text(0.5, 1.0, 'Weather information')

# %% [markdown]
# # Bar graph

# %%
col_1 = ['google' , 'fb' , 'x']
col_2 = [350 , 200 , 500]
plt.bar(col_1 , col_2)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Histogram
#
#
# less 100 Normal
#
# 100 To 125 --> prediabetic
#
# 125 --> Diabetic

# %%
blood_sugar = [113 , 90 , 145 , 130 , 95 , 114 , 89 , 150 , 140 , 77 , 84]

# %%
plt.hist(blood_sugar)
# Out:
# (array([2., 2., 1., 0., 1., 1., 0., 1., 1., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar , bins= [77,100 , 125 , 150])
# Out:
# (array([5., 2., 4.]),
#  array([ 77., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

df = sns.load_dataset('titanic')
df['age'].fillna(df['age'].mean() , inplace = True)
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df['age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
df['age'].min()
# Out:
# 0.42

# %%
df['age'].max()
# Out:
# 80.0

# %%
plt.hist(df['age'] , bins = [0.42 , 18 , 80])
# Out:
# (array([113., 778.]),
#  array([ 0.42, 18.  , 80.  ]),
#  <BarContainer object of 2 artists>)

# %%
plt.hist(df['age'] , bins = [0 , 18,29, 50 , 100])
# Out:
# (array([113., 251., 453.,  74.]),
#  array([  0.,  18.,  29.,  50., 100.]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(df['age'] , bins = [ 18,29, 50 , 100])
# Out:
# (array([251., 453.,  74.]),
#  array([ 18.,  29.,  50., 100.]),
#  <BarContainer object of 3 artists>)

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

# %%
plt.hist([blood_sugar_men , blood_sugar_women] , bins= [77,100 , 125 , 150] 
         , label = ['Men' , 'Women'])

plt.legend()

# %%
plt.hist([blood_sugar_men , blood_sugar_women] , bins= [77,100 , 125 , 150] 
         , label = ['Men' , 'Women'] , color = ['green' , 'magenta'] , histtype = 'stepfilled')

plt.legend()

# %%
plt.hist(df['age'] )
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Scatter plot

# %%
plt.scatter(df['age'] , df['fare'])

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.boxplot(df['total_bill'])
plt.show()

# %%
sns.boxplot(x = 'total_bill' , data = df)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.displot(x = 'total_bill' , data = df)
# Out:
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(x = 'total_bill' , data = df , kde = True)
# Out:
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = df)
# Out:
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = df )
# Out:
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = df , kind = 'box')
# Out:
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.pairplot(df)
# Out:
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Nilam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Python , Git , Deployments
